# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data_inside = pd.read_csv('inside_data.csv')
data_outside = pd.read_csv('outside_data.csv')

# %%
plt.plot(data_inside["PM25"],label = "PM25 Inside")
plt.plot(data_outside["PM25"],label = "PM25 Outside")
plt.legend()
plt.show()

# %%
plt.hist(data_inside["PM25"],label = "PM25 Inside")
plt.hist(data_outside["PM25"],label = "PM25 Outside")
plt.legend()
plt.show()

# %%
plt.plot(data_inside["PM10"],label = "PM10 Inside")
plt.plot(data_outside["PM10"],label = "PM10 Outside")
plt.legend()
plt.show()

# %%
plt.hist(data_inside["PM10"],label = "PM10 Inside")
plt.hist(data_outside["PM10"],label = "PM10 Outside")
plt.legend()
plt.show()

# %%
plt.plot(data_inside["Temperature"],label = "Temperature Inside")
plt.plot(data_outside["Temperature"],label = "Temperature Outside")
plt.legend()
plt.show()

# %%
plt.hist(data_inside["Temperature"],label = "Temperature Inside")
plt.hist(data_outside["Temperature"],label = "Temperature Outside")
plt.legend()
plt.show()

# %%
plt.plot(data_inside["Humidity"],label = "Humidity Inside")
plt.plot(data_outside["Humidity"],label = "Humidity Outside")
plt.legend()
plt.show()

# %%
plt.hist(data_inside["Humidity"],label = "Humidity Inside")
plt.hist(data_outside["Humidity"],label = "Humidity Outside")
plt.legend()
plt.show()

# %%
plt.plot(data_inside["Pressure"],label = "Presssure Inside")
plt.plot(data_outside["Pressure"],label = "Pressure Outside")
plt.legend()
plt.show()

# %%
plt.hist((data_outside["Pressure"])[1:],label = "Pressure Outside")
plt.hist((data_inside["Pressure"])[1:],label = "Presssure Inside")
plt.legend()
plt.show()

# %% [markdown]
# 3.a: Temperature and humidity were a little different but all the others were very similar. Temprature and humidity decreased when we went outside.

# %%
PM25_imeanstd = np.std(data_inside["PM25"])/17.32
print(np.std(data_inside["PM25"]))
print(PM25_imeanstd)

PM25_omeanstd = np.std(data_outside["PM25"])/17.32
print(np.std(data_outside["PM25"]))
print(PM25_omeanstd)
# Out:
# 0.3552467795046452
# 0.020510784036064968
# 0.3649744678228748
# 0.021072428858133648

# %%
PM10_imeanstd = np.std(data_inside["PM10"])/17.32
print(np.std(data_inside["PM10"]))
print(PM10_imeanstd)

PM10_omeanstd = np.std(data_outside["PM10"])/17.32
print(np.std(data_outside["PM10"]))
print(PM10_omeanstd)
# Out:
# 0.6546375903340104
# 0.03779662761743709
# 0.43252562471447314
# 0.024972611126701683

# %%
Temperature_imeanstd = np.std(data_inside["Temperature"])/17.32
print(np.std(data_inside["Temperature"]))
print(Temperature_imeanstd)

Temperature_omeanstd = np.std(data_outside["Temperature"])/17.32
print(np.std(data_outside["Temperature"]))
print(Temperature_omeanstd)
# Out:
# 0.6300948733537605
# 0.0363796116255058
# 1.0208184876834248
# 0.058938711760012974

# %%
Humidity_imeanstd = np.std(data_inside["Humidity"])/17.32
print(np.std(data_inside["Humidity"]))
print(Humidity_imeanstd)

Humidity_omeanstd = np.std(data_outside["Humidity"])/17.32
print(np.std(data_outside["Humidity"]))
print(Humidity_omeanstd)
# Out:
# 3.0268552385601613
# 0.1747606950669839
# 3.5847767989306085
# 0.2069732562892961

# %%
Pressure_imeanstd = np.std(data_inside["Pressure"])/17.32
print(np.std(data_inside["Pressure"]))
print(Pressure_imeanstd)

Pressure_omeanstd = np.std(data_outside["Pressure"])/17.32
print(np.std(data_outside["Pressure"]))
print(Pressure_omeanstd)
# Out:
# 18.189684074532558
# 1.0502127063817874
# 18.150192434534063
# 1.0479325885989643

# %% [markdown]
# 3.b: Statistically, the means are not separated by more than three sigma. There were differences in the temprature and humidity that could be seen in the graphs and the statistics but were not very large.
