# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv(r'D:\Usuario\Downloads\Loc1_session1_group2_2024-04-17_14-50-30.csv') # Loc 1
data2 = pd.read_csv(r'D:\Usuario\Downloads\Loc1_session1_group3_2024-04-17_15-13-13.csv') # Loc 2
data3 = pd.read_csv(r'D:\Usuario\Downloads\Loc1_session1_group4_2024-04-17_15-34-35.csv') # Loc 3
data4 = pd.read_csv(r'D:\Usuario\Downloads\Loc1_session1_group5_2024-04-17_15-55-43.csv') # Loc 4
data5 = pd.read_csv(r'D:\Usuario\Downloads\Loc1_session1_group6_2024-04-17_16-21-01.csv') # Loc 5
data6 = pd.read_csv(r'D:\Usuario\Downloads\Loc1_session1_group7_2024-04-24_15-00-04.csv') # Loc 6
data7 = pd.read_csv(r'D:\Usuario\Downloads\Loc1_session8_group1_2024-04-24_15-26-06.csv') # Loc 7

# %%
pm25_1 = data1['PM25'][40:450]
pm10_1 = data1['PM10'][40:450]
plt.plot(pm25_1, '-o', label = "PM25")
plt.plot(pm10_1, '-rx', label = "PM10")
plt.xlabel("Time")
plt.ylabel("PM")
plt.legend(loc="upper left")
plt.title("PM10 and PM2.5 at Etcheverry Breezeway")
plt.show()

# %%
pm25_2 = data2['PM25'][40:450]
pm10_2 = data2['PM10'][40:450]
plt.plot(pm25_2, '-o', label = "PM25")
plt.plot(pm10_2, '-rx', label = "PM10")
plt.xlabel("Time")
plt.ylabel("PM")
plt.legend(loc="upper left")
plt.title("PM10 and PM2.5 at McLaughlin Patio")
plt.show()

# %%
pm25_3 = data3['PM25'][40:450]
pm10_3 = data3['PM10'][40:450]
plt.plot(pm25_3, '-o', label = "PM25")
plt.plot(pm10_3, '-rx', label = "PM10")
plt.xlabel("Time")
plt.ylabel("PM")
plt.legend(loc="upper left")
plt.title("PM10 and PM2.5 between Pimentel and Latimer")
plt.show()

# %%
pm25_4 = data4['PM25'][40:450]
pm10_4 = data4['PM10'][40:450]
plt.plot(pm25_4, '-o', label = "PM25")
plt.plot(pm10_4, '-rx', label = "PM10")
plt.xlabel("Time")
plt.ylabel("PM")
plt.legend(loc="upper left")
plt.title("PM10 and PM2.5 by Haas and Optometry")
plt.show()

# %%
pm25_5 = data5['PM25'][40:450]
pm10_5 = data5['PM10'][40:450]
plt.plot(pm25_5, '-o', label = "PM25")
plt.plot(pm10_5, '-rx', label = "PM10")
plt.xlabel("Time")
plt.ylabel("PM")
plt.legend(loc="upper left")
plt.title("PM10 and PM2.5 in Foothill Parking Lot")
plt.show()

# %%
pm25_6 = data6['PM25'][40:450]
pm10_6 = data6['PM10'][40:450]
plt.plot(pm25_6, '-o', label = "PM25")
plt.plot(pm10_6, '-rx', label = "PM10")
plt.xlabel("Time")
plt.ylabel("PM")
plt.legend(loc="upper left")
plt.title("PM10 and PM2.5 by Gateway Construction")
plt.show()

# %%
pm25_7 = data7['PM25'][40:450]
pm10_7 = data7['PM10'][40:450]
plt.plot(pm25_7, '-o', label = "PM25")
plt.plot(pm10_7, '-rx', label = "PM10")
plt.xlabel("Time")
plt.ylabel("PM")
plt.legend(loc="upper center")
plt.title("PM10 and PM2.5 by Baseball Stadium")
plt.show()
