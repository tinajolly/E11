# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data1 = pd.read_csv('Loc1_session1_group2_2024-04-17_14-50-30.csv') # Etcheverry Breezeway
data2 = pd.read_csv('Loc1_session1_group3_2024-04-17_15-13-13.csv') # Mclaughlin Patio
data3 = pd.read_csv('Loc1_session1_group4_2024-04-17_15-34-35.csv') # Between Pimentel and Latimer
data4 = pd.read_csv('Loc1_session1_group5_2024-04-17_15-55-43.csv') # By Haas and Optometry
data5 = pd.read_csv('Loc1_session1_group6_2024-04-17_16-21-01.csv') # Foothill Parking Lot
data6 = pd.read_csv('Loc1_session1_group7_2024-04-24_15-00-04.csv') # By Gateway Construction
data7 = pd.read_csv('Loc1_session8_group1_2024-04-24_15-26-06.csv') # By the Baseball Stadium
print(len(data1))
print(len(data2))
print(len(data3))
print(len(data4))
print(len(data5))
# Out:
# 462
# 456
# 455
# 459
# 466

# %%
def stats_fun(data,str1,str2,str3):
    data = data[40:450]
    mean = np.mean(data)
    std = np.std(data)
    thstd = np.sqrt(mean)
    thstd2 = np.sqrt(np.sum(data))/len(data)
    
    plt.plot(data)
    plt.title(str1 + ' vs Time ' + str2)
    plt.xlabel('Time')
    plt.ylabel(str1)
    #plt.savefig('plot ' + str3)
    plt.show()
    
    plt.hist(data)
    plt.title('Distribution of ' + str1 + ' ' + str2)
    plt.xlabel(str1)
    plt.ylabel('Frequency')
    #plt.savefig('hist ' + str3)
    plt.show()
    
    print('Mean =',mean)
    print('Standard Deviation =',std)
    
    if str1 == 'Counts per 2 Seconds':
        exstdstd = thstd/(np.sqrt(2*np.sqrt(len(data))))
        cps = mean/2
        cpsstd = std/2
        print('Theoretical Standard Deviation =',thstd)
        print('Theoretical Standard Deviation 2 =',thstd2)
        print('Uncertainty on the Experimental Standard Deviation =',exstdstd)
        print('Counts per Second =',cps)
        print('Uncertainty on CPS =',cpsstd)

# %%
stats_fun(data1['counts'],'Counts per 2 Seconds','on Etcheverry Breezeway','counts etcheverry')
# Out:
# Mean = 38.392682926829266
# Standard Deviation = 4.226737786295567
# Theoretical Standard Deviation = 6.196182932001706
# Theoretical Standard Deviation 2 = 0.30600766340965585
# Uncertainty on the Experimental Standard Deviation = 0.9736733181823954
# Counts per Second = 19.196341463414633
# Uncertainty on CPS = 2.1133688931477836

# %%
stats_fun(data1['Temperature'],'Temperature','on Etcheverry Breezeway','counts etcheverry')
# Out:
# Mean = 27.536273580411585
# Standard Deviation = 0.2787413555898581

# %%
stats_fun(data1['PM25'],'PM25','on Etcheverry Breezeway','counts etcheverry')
# Out:
# Mean = 1.9182926829268292
# Standard Deviation = 0.9119970112248422

# %%
stats_fun(data2['counts'],'Counts per 2 Seconds','on McLaughlin Patio','counts mclaughlin')
# Out:
# Mean = 39.334146341463416
# Standard Deviation = 4.126127917108277
# Theoretical Standard Deviation = 6.271694056749214
# Theoretical Standard Deviation 2 = 0.30973689204912647
# Uncertainty on the Experimental Standard Deviation = 0.9855391988704659
# Counts per Second = 19.667073170731708
# Uncertainty on CPS = 2.0630639585541384

# %%
stats_fun(data2['PM25'],'PM25','on Mclaughlin Patio','counts mclaughlin')
# Out:
# Mean = 2.6109756097560974
# Standard Deviation = 0.6395513094771171

# %%
stats_fun(data3['counts'],'Counts per 2 Seconds','Between Pimentel and Latimer','counts pimentel')
# Out:
# Mean = 48.31951219512195
# Standard Deviation = 4.635794957070214
# Theoretical Standard Deviation = 6.951223791183963
# Theoretical Standard Deviation 2 = 0.3432964735743584
# Uncertainty on the Experimental Standard Deviation = 1.092321064188464
# Counts per Second = 24.159756097560976
# Uncertainty on CPS = 2.317897478535107

# %%
stats_fun(data3['PM25'],'PM25','Between Pimentel and Latimer','counts pimentel')
# Out:
# Mean = 2.175609756097561
# Standard Deviation = 0.7405602651008779

# %%
stats_fun(data4['counts'],'Counts per 2 Seconds','By Haas and Optometry','counts Haas')
# Out:
# Mean = 34.78170731707317
# Standard Deviation = 4.321729781531998
# Theoretical Standard Deviation = 5.8976018276137605
# Theoretical Standard Deviation 2 = 0.2912617937194411
# Uncertainty on the Experimental Standard Deviation = 0.9267540361265868
# Counts per Second = 17.390853658536585
# Uncertainty on CPS = 2.160864890765999

# %%
stats_fun(data4['PM25'],'PM25','By Haas and Optometry','counts Haas')
# Out:
# Mean = 2.0170731707317073
# Standard Deviation = 0.7884540102969625

# %%
stats_fun(data5['counts'],'Counts per 2 Seconds','in Foothill Parking Lot','counts foothill')
# Out:
# Mean = 39.93292682926829
# Standard Deviation = 4.130760718874582
# Theoretical Standard Deviation = 6.319250495847454
# Theoretical Standard Deviation 2 = 0.3120855371695563
# Uncertainty on the Experimental Standard Deviation = 0.9930122571009729
# Counts per Second = 19.966463414634145
# Uncertainty on CPS = 2.065380359437291

# %%
stats_fun(data5['PM25'],'PM25','in Foothill Parking Lot','counts foothill')
# Out:
# Mean = 1.354878048780488
# Standard Deviation = 0.7352040431933848

# %%
stats_fun(data6['counts'],'Counts per 2 Seconds','by Gateway Construction','counts gateway')
# Out:
# Mean = 47.80487804878049
# Standard Deviation = 4.568019863456462
# Theoretical Standard Deviation = 6.914107176547128
# Theoretical Standard Deviation 2 = 0.34146341463414637
# Uncertainty on the Experimental Standard Deviation = 1.0864885286210433
# Counts per Second = 23.902439024390244
# Uncertainty on CPS = 2.284009931728231

# %%
stats_fun(data6['PM25'],'PM25','by Gateway Construction','counts gateway')
# Out:
# Mean = 0.875609756097561
# Standard Deviation = 0.8898562470380359

# %%
stats_fun(data7['counts'],'Counts per 2 Seconds','by Baseball Stadium','counts baseball')
# Out:
# Mean = 32.91341463414634
# Standard Deviation = 4.200660871209174
# Theoretical Standard Deviation = 5.737021407851494
# Theoretical Standard Deviation 2 = 0.28333129205736085
# Uncertainty on the Experimental Standard Deviation = 0.9015202959576959
# Counts per Second = 16.45670731707317
# Uncertainty on CPS = 2.100330435604587

# %%
stats_fun(data7['PM25'],'PM25','by Baseball Stadium','counts baseball')
# Out:
# Mean = 0.7097560975609756
# Standard Deviation = 0.6371831601164537
