# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('air_quality_data.csv')

# %%
plt.hist(data["PM25"],bins=5)
plt.show()

# %%
plt.hist(data["PM10"],bins=5)
plt.show()

# %% [markdown]
# The PM25 and PM10 only had values of zero and one. There was more variations in the data recorded for particles of size 0.3 mircometers.
